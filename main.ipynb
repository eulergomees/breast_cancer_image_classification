# %% [markdown]
# # Breast cancer image classification

# %%
from IPython.display import display, HTML
from babel.util import missing

display(HTML("<style>.container {widht: 100% !important;}</style>"))
# Out:
# <style>.container {widht: 100% !important;}</style>

# %% [markdown]
# ## Import packages

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # GPU check

# %%
if torch.cuda.is_available():
    print("__CUDNN VERSION:", torch.backends.cudnn.version())
    print("Device Name:", torch.cuda.get_device_name(0)) # 0 for the first GPU
else:
    print("CUDA is not available.")
# Out:
# __CUDNN VERSION: 91002
# Device Name: NVIDIA GeForce RTX 5070
